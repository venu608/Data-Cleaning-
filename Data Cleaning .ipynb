# %%
### DATA Cleaning

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\Dell\Downloads\Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# ...

# %%
df = df.drop(columns ="Not_Useful_Column")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# ...

# %%
##df ["Last_Name"]= df ["Last_Name"].str.lstrip("...")
##df ["Last_Name"]= df ["Last_Name"].str.lstrip("/")
##df ["Last_Name"]= df ["Last_Name"].str.rstrip("_")
df ["Last_Name"] =df ["Last_Name"].str.strip("123._/")

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
df["Phone_Number"]=df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')

# %%
df["Phone_Number"]=df["Phone_Number"].apply(lambda x: str(x))

# %%
df["Phone_Number"]=df["Phone_Number"].apply(lambda x: x [0:3]+ ''+ x [3:6]+ ''+x[6:10])

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White          nan
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger          nan
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN          N/a
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee          nan
# 11        1012      Harry      Potter          nan
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
df["Phone_Number"]=df["Phone_Number"].str.replace('nan','')

# %%
df["Phone_Number"]=df["Phone_Number"].str.replace('N/a','')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df["Address"].str.split(',',1, expand=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[206], line 1
# ----> 1 df["Address"].str.split(',',1, expand=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.split() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
df[["street_Address", "state", "zip_code"]] =df["Address"].str.split(',',1, expand=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 df[["street_Address", "state", "zip_code"]] =df["Address"].str.split(',',1, expand=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.split() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df["Paying Customer"]=df["Paying Customer"].str.replace("Yes","Y")
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df["Paying Customer"]=df["Paying Customer"].str.replace("No","N")
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df.replace('N/a','')
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df.fillna('')
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df=df.replace('N/a','')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df= df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df["Do_Not_Contact"]=df["Do_Not_Contact"].str.replace("No","N")
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 7         1008   Sherlock      Holmes   876-678-34
# 9         1010      Peter      Parker   123-545-54
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 19        1020     Anakin   Skywalker   876-678-34
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire               Y              N
# 3   980 Paper Avenue, Pennsylvania, 18503               Y              Y
# 4                        123 Dragons Road               Y              N
# ...

# %%
for x in df.index:
    if df.loc[x,"Do_Not_Contact"]== 'Yes':
      df.drop(x, inplace=True)

df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 7         1008   Sherlock      Holmes   876-678-34
# 9         1010      Peter      Parker   123-545-54
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 19        1020     Anakin   Skywalker   876-678-34
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire               Y              N
# 3   980 Paper Avenue, Pennsylvania, 18503               Y              Y
# 4                        123 Dragons Road               Y              N
# ...

# %%
for x in df.index:
    if df.loc[x,"Phone_Number"]== '':
      df.drop(x, inplace=True)

df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 7         1008   Sherlock      Holmes   876-678-34
# 9         1010      Peter      Parker   123-545-54
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 19        1020     Anakin   Skywalker   876-678-34
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire               Y              N
# 3   980 Paper Avenue, Pennsylvania, 18503               Y              Y
# 4                        123 Dragons Road               Y              N
# ...

# %%
df.reset_index(drop=True)
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1004     Dwight     Schrute   123-543-23
# 2         1005        Jon        Snow   876-678-34
# 3         1008   Sherlock      Holmes   876-678-34
# 4         1010      Peter      Parker   123-545-54
# 5         1013        Don      Draper   123-543-23
# 6         1014     Leslie       Knope   876-678-34
# 7         1015       Toby  Flenderson   304-762-24
# 8         1016        Ron     Weasley   123-545-54
# 9         1017   Michael        Scott   123-643-97
# 10        1020     Anakin   Skywalker   876-678-34
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire               Y              N
# 1   980 Paper Avenue, Pennsylvania, 18503               Y              Y
# 2                        123 Dragons Road               Y              N
# ...

# %%
## Conculsion

# %%
#when i absorve the data in that some unstructured Data Like (-,_./) like this 
# i cleaned the data 
# remove null values 
#  drop columns where they dont need in this data 
# and Ajust the same formate the every data in one formate 
# and  removing  the nan Na Value and Final change the index number and final data
